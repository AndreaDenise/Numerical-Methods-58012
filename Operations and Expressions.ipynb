# %%
#BOOLEAN OPERATORS

print(10>9)
print(10<9)
print(10==9)

# %%
a = 10
b = 9

print(a==b)
# Out:
# False

# %%
print(bool(1))
print(bool("Andrea"))
# Out:
# True
# True

# %%
##functions can return a boolean
def my_Function():
  return False

print(my_Function())
# Out:
# False

# %%
if my_Function():
  print("YEAH")
else:
  print("NAUR")
# Out:
# NAUR

# %%
#APPLICATION 1
a=6
b=7

print(a==b)
print(a!=b)
# Out:
# False
# True

# %%
#Python Operators
a = 10
b = 5
print(a-b)
print(a+b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# 5
# 15
# 0
# 2
# 100000

# %%
#BITWISE OPERATORS
a = 60
b = 13

print(a&b)
print(a|b)
print(a^b)
# Out:
# 12
# 61
# 49

# %%
#Assignment Operators
a += 3
print(a)
# Out:
# 63

# %%
#LOgical operators
x = True
y = False 

print(x and y)
print(x or y)
print(not(x and y))
# Out:
# False
# True
# True

# %%
#Identity Operators
